# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data_sets/survey.csv')
df.columns
# Out:
# Index(['Timestamp', 'Age (in years)', 'Gender', 'Daily Screen time ',
#        'Tea or Coffee consumption per day',
#        'How many times a week do you exercise?',
#        'How stressful is your daily life? (5 being the highest)',
#        'How many hours do you sleep per night in average? ',
#        'How many times do you snore ?',
#        'How many times do you wake up at night ?',
#        'Do you have following health conditions ?',
#        '  Do you feel tired during the day?  '],
#       dtype='object')

# %%
df.drop(columns=['Timestamp', 'Tea or Coffee consumption per day','Daily Screen time ','How many times do you snore ?','How many times do you wake up at night ?','  Do you feel tired during the day?  '], inplace=True)

# %%
df.head()
# Out:
#    Age (in years)  Gender How many times a week do you exercise?  \
# 0              22    Male                                 Rarely
# 1              24    Male                                  Daily
# 2              25    Male                                 Rarely
# 3              22    Male                       3-5 times a week
# 4              22  Female                                  Daily
#
#    How stressful is your daily life? (5 being the highest)  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  4
#
#    How many hours do you sleep per night in average?   \
# 0                                                6.0
# 1                                                6.0
# 2                                                7.0
# 3                                                6.0
# 4                                                8.0
#
#   Do you have following health conditions ?
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                        Obesity (BMI > 30)
# 4                                       NaN

# %%
df.columns
# Out:
# Index(['Age (in years)', 'Gender', 'How many times a week do you exercise?',
#        'How stressful is your daily life? (5 being the highest)',
#        'How many hours do you sleep per night in average? ',
#        'Do you have following health conditions ?'],
#       dtype='object')

# %%
df.rename(columns = {
    'Age (in years)': 'Age',
    'Gender': 'Gender',
    'How many times a week do you exercise?': 'Physical Activity Level',
    'How stressful is your daily life? (5 being the highest)': 'Stress Level',
    'How many hours do you sleep per night in average? ': 'Sleep Duration',
    'Do you have following health conditions ?': 'Health Conditions',
}, inplace=True)

# %%
def clean_activity_level(value):
    if "3-5 times a week" in value:
        return "3-5 times a week"
    elif "Rarely" in value:
        return "Rarely"
    return value  # Keep the original if no changes

# Apply the function to clean the column
df['Physical Activity Level'] = df['Physical Activity Level'].apply(clean_activity_level)

# %%
def assign_random_activity(value):
    if value == "Daily":
        return random.randint(80, 100)  # Daily → 80 to 100
    elif value == "3-5 times a week":
        return random.randint(50, 79)  # 3-5 times a week → 50 to 79
    elif value == "Rarely":
        return random.randint(10, 49)  # Rarely
    else:
        return None
    df['Physical Activity Level'] = df['Physical Activity Level'].apply(assign_random_activity)

# %%
df.head()
# Out:
#    Age  Gender Physical Activity Level  Stress Level  Sleep Duration  \
# 0   22    Male                  Rarely             3             6.0
# 1   24    Male                   Daily             3             6.0
# 2   25    Male                  Rarely             3             7.0
# 3   22    Male        3-5 times a week             3             6.0
# 4   22  Female                   Daily             4             8.0
#
#     Health Conditions
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3  Obesity (BMI > 30)
# 4                 NaN

# %%
df.columns.str.strip()
if 'How many hours do you sleep per night in average?' in df.columns.str.strip():
    df.rename(columns={'How many hours do you sleep per night in average?':'Sleep Duration'}, inplace=True)

# %%
df.head()
df['Health Conditions'].unique()
# Out:
# array([nan, 'Obesity (BMI > 30)', 'Diabetes',
#        'Hypertension ( High blood pressure )'], dtype=object)

# %%
import random
def blood_pressure(df):
    for i in range(len(df)):
        health_condition = df.at[i, 'Health Conditions']
        
        if pd.isna(health_condition):  # If health condition is NaN
            df.at[i, 'Blood Pressure'] = random.choice(["120/80", "115/75", "130/85"])  # Normal BP
            df.at[i, 'BMI Category'] = 'Normal'
        
        elif health_condition == 'Obesity (BMI > 30)':
            df.at[i, 'Blood Pressure'] = random.choice(["130/85", "140/90", "150/100"])  # Higher BP
            df.at[i, 'BMI Category'] = 'Overweight'
        
        elif health_condition == 'Hypertension ( High blood pressure )':
            df.at[i, 'Blood Pressure'] = random.choice(["140/95", "150/100", "160/110"])  # High BP
            df.at[i, 'BMI Category'] = random.choice(['Normal', 'Overweight'])

    return df

# Apply the function to the dataframe
df = blood_pressure(df)

df.columns
# Out:
# Index(['Age', 'Gender', 'Physical Activity Level', 'Stress Level',
#        'Sleep Duration', 'Health Conditions', 'Blood Pressure',
#        'BMI Category'],
#       dtype='object')

# %%
df.drop(columns=['Health Conditions'], inplace=True)

# %%
df.head()
df.dtypes
df['Sleep Duration'].unique()
# Out:
# array([ 6. ,  7. ,  8. ,  9. ,  5. ,  4. , 10. ,  6.5,  5.5,  4.5])

# %%
def quality_of_sleep(duration):
    if 7 <= duration <= 9:
        return "Good"
    elif 5 <= duration < 7:
        return "Average"
    else:
        return "Poor"

# Apply the function to the DataFrame
df["Quality of Sleep"] = df["Sleep Duration"].apply(quality_of_sleep)

# Show the updated DataFrame
df.head()
# Out:
#    Age  Gender Physical Activity Level  Stress Level  Sleep Duration  \
# 0   22    Male                  Rarely             3             6.0
# 1   24    Male                   Daily             3             6.0
# 2   25    Male                  Rarely             3             7.0
# 3   22    Male        3-5 times a week             3             6.0
# 4   22  Female                   Daily             4             8.0
#
#   Blood Pressure BMI Category Quality of Sleep
# 0         120/80       Normal          Average
# 1         115/75       Normal          Average
# 2         115/75       Normal             Good
# 3        150/100   Overweight          Average
# 4         130/85       Normal             Good

# %%
df['Stress Level'] = df['Stress Level'].apply(lambda x: 2*x)
df.head()
# Out:
#    Age  Gender Physical Activity Level  Stress Level  Sleep Duration  \
# 0   22    Male                  Rarely             6             6.0
# 1   24    Male                   Daily             6             6.0
# 2   25    Male                  Rarely             6             7.0
# 3   22    Male        3-5 times a week             6             6.0
# 4   22  Female                   Daily             8             8.0
#
#   Blood Pressure BMI Category Quality of Sleep
# 0         120/80       Normal          Average
# 1         115/75       Normal          Average
# 2         115/75       Normal             Good
# 3        150/100   Overweight          Average
# 4         130/85       Normal             Good

# %%
def assign_random_activity(value):
    if value == "Daily":
        return random.randint(80, 100)  # Daily → 80 to 100
    elif value == "3-5 times a week":
        return random.randint(50, 79)  # 3-5 times a week → 50 to 79
    elif value == "Rarely":
        return random.randint(20, 49)  # Rarely → 1 to 49
    else:
        return None  # For any other category

# Apply the function to the 'Physical Activity Level' column
df["Physical Activity Level"] = df["Physical Activity Level"].apply(assign_random_activity)

# Show the updated DataFrame
print(df)
# Out:
#     Age  Gender  Physical Activity Level  Stress Level  Sleep Duration  \
# 0    22    Male                       48             6             6.0
# 1    24    Male                       85             6             6.0
# 2    25    Male                       23             6             7.0
# 3    22    Male                       60             6             6.0
# 4    22  Female                       85             8             8.0
# 5    31  Female                       68             4             6.0
# 6    22  Female                       38            10             6.0
# 7    37  Female                       82             2             7.0
# 8    40    Male                       94             4             7.0
# 9    22    Male                       44             4             7.0
# 10   13    Male                       85             8             9.0
# 11   23    Male                       57             6             5.0
# 12   37  Female                       54             2             6.0
# 13   23    Male                       42             8             5.0
# 14   25    Male                       90             4             5.0
# 15   22    Male                       49             8             7.0
# 16   22    Male                       33             4             7.0
# 17   34  Female                       88             2             8.0
# 18   32    Male                       89             6             7.0
# 19   22    Male                       74            10             4.0
# 20   32    Male                       83             6             7.0
# 21   27  Female                       32             2            10.0
# 22   28  Female                       44             6             7.0
# 23   35    Male                       45             2             7.0
# 24   29    Male                       31             2             6.5
# 25   25  Female                       72            10             6.0
# 26   18    Male                       50             4             7.0
# 27   22    Male                       38             6             8.0
# 28   18    Male                       39             6             6.5
# 29   22    Male                       23             6             5.5
# 30   20    Male                       32             6             6.0
# 31   21    Male                       30             8             7.0
# 32   21    Male                       39             6             8.0
# 33   20    Male                       44             2             5.0
# 34   20    Male                       29             2             5.0
# 35   21    Male                       25             6             7.0
# 36   21    Male                       47             4             7.0
# 37   31    Male                       28             4             7.0
# 38   19    Male                       34             6             7.0
# 39   21  Female                       35             6             9.0
# 40   21    Male                       35            10             7.0
# 41   18    Male                       68            10             8.0
# 42   23    Male                       25             8             8.0
# 43   21    Male                       21             4             4.5
# 44   20    Male                       45             6             7.0
# 45   23    Male                       38             6             5.0
# 46   22    Male                       22             6             6.0
# 47   38    Male                       75             2             7.0
#
#    Blood Pressure BMI Category Quality of Sleep
# 0          120/80       Normal          Average
# 1          115/75       Normal          Average
# 2          115/75       Normal             Good
# 3         150/100   Overweight          Average
# 4          130/85       Normal             Good
# 5          120/80       Normal          Average
# 6          130/85       Normal          Average
# 7          115/75       Normal             Good
# 8             NaN          NaN             Good
# 9          130/85       Normal             Good
# 10         115/75       Normal             Good
# 11        150/100   Overweight          Average
# 12         115/75       Normal          Average
# 13         130/85       Normal          Average
# 14         130/85       Normal          Average
# 15         120/80       Normal             Good
# 16         140/90   Overweight             Good
# 17         130/85   Overweight             Good
# 18        160/110   Overweight             Good
# 19         130/85       Normal             Poor
# 20        150/100   Overweight             Good
# 21         130/85       Normal             Poor
# 22         120/80       Normal             Good
# 23         115/75       Normal             Good
# 24         115/75       Normal          Average
# 25         130/85       Normal          Average
# 26         120/80       Normal             Good
# 27         120/80       Normal             Good
# 28         120/80       Normal          Average
# 29         115/75       Normal          Average
# 30         120/80       Normal          Average
# 31         130/85       Normal             Good
# 32         115/75       Normal             Good
# 33         130/85       Normal          Average
# 34         120/80       Normal          Average
# 35         120/80       Normal             Good
# 36         120/80       Normal             Good
# 37         130/85       Normal             Good
# 38        150/100   Overweight             Good
# 39         130/85       Normal             Good
# 40         130/85       Normal             Good
# 41         120/80       Normal             Good
# 42         115/75       Normal             Good
# 43         130/85   Overweight             Poor
# 44         120/80       Normal             Good
# 45         120/80       Normal          Average
# 46         130/85       Normal          Average
# 47         130/85       Normal             Good

# %%
df.head()
# Out:
#    Age  Gender  Physical Activity Level  Stress Level  Sleep Duration  \
# 0   22    Male                       48             6             6.0
# 1   24    Male                       85             6             6.0
# 2   25    Male                       23             6             7.0
# 3   22    Male                       60             6             6.0
# 4   22  Female                       85             8             8.0
#
#   Blood Pressure BMI Category Quality of Sleep
# 0         120/80       Normal          Average
# 1         115/75       Normal          Average
# 2         115/75       Normal             Good
# 3        150/100   Overweight          Average
# 4         130/85       Normal             Good

# %%
df.to_csv('data_sets/refined_survey.csv')
